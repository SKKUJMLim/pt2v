# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import numpy as np
import urllib.request
import sys, os
import glob
from PIL import Image

# (선택) decord로 비디오 읽기 – 안 쓰고 직접 frame 텐서를 만들고 싶으면 이 부분만 바꿔도 됨
from decord import VideoReader, cpu

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from model import Model

# %%
# -----------------------------------
# 1. device 설정 & 모델 / preprocessor 로드
# -----------------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"

# torch.hub에서 preprocessor / encoder 로드
processor = torch.hub.load('facebookresearch/vjepa2', 'vjepa2_preprocessor')
loaded  = torch.hub.load('facebookresearch/vjepa2', 'vjepa2_vit_giant')

if isinstance(loaded, tuple):
    vjepa2_encoder = loaded[0]    # encoder만 사용
else:
    vjepa2_encoder = loaded

vjepa2_encoder = vjepa2_encoder.to(device).eval()
# Out:
# Using cache found in C:\Users\JM/.cache\torch\hub\facebookresearch_vjepa2_main
# Using cache found in C:\Users\JM/.cache\torch\hub\facebookresearch_vjepa2_main

# %%
# -----------------------------------
# V-JEPA2 patch_embed3D의 temporal kernel size = 2 임을 검증하는 코드 
# 시간축: 2프레임을 동시에 본다
# 공간축: 16×16 픽셀을 동시에 본다
# -----------------------------------
pe = vjepa2_encoder.patch_embed
print(pe)
print(pe.proj.kernel_size)
print(pe.proj.stride)
# Out:
# PatchEmbed3D(
#   (proj): Conv3d(3, 1408, kernel_size=(2, 16, 16), stride=(2, 16, 16))
# )
# (2, 16, 16)
# (2, 16, 16)

# %% [markdown]
# # 구조적으로 Predictor가 있는지 직접 확인하는 코드

# %%
print([name for name, _ in vjepa2_encoder.named_children()])
# Out:
# ['patch_embed', 'blocks', 'norm']

# %%
print(type(vjepa2_encoder))
print(sum(p.numel() for p in vjepa2_encoder.parameters()))
print(any("predictor" in n.lower() for n, _ in vjepa2_encoder.named_modules()))
# Out:
# <class 'src.models.vision_transformer.VisionTransformer'>
# 1012173952
# False

# %%
# ---------------------------------------------------
# 2. frames 폴더에서 _0.jpg ~ _7.jpg 읽기
# ---------------------------------------------------
# frames_dir = "../A horse galloping on a street"
frames_dir = "A match is being lowered into a glass of water"
# frames_dir = "../original_A match is being lowered into a glass of water"

# 파일 목록 정렬 (_0.jpg, _1.jpg, ... 순서 보장)
# frame_paths = glob.glob(os.path.join(frames_dir, "*.png"))
frame_paths = glob.glob(os.path.join(frames_dir, "*.jpg"))

def frame_key(path):
    # 예: path = "frames/_3.jpg" -> stem = "_3" -> idx = 3
    name = os.path.splitext(os.path.basename(path))[0]  # "_3"
    idx = int(name.split("_")[-1])
    return idx

frame_paths = sorted(frame_paths, key=frame_key)

print("frames:", frame_paths)

# 각 프레임을 np.ndarray(H,W,3)로 읽어서 리스트로 만들기
imgs = [Image.open(p).convert("RGB") for p in frame_paths]
buffer = [np.array(im) for im in imgs]   # <-- ★ 여기! 리스트로 전달할 애
# Out:
# frames: []

# %%
# ---------------------------------------
# 3) processor로 clip 생성
# ---------------------------------------
inputs = processor(buffer)   # 보통 [clip_tensor] 형태

if isinstance(inputs, list):
    clip = inputs[0]
else:
    clip = inputs

print("clip type:", type(clip))
print("clip shape:", clip.shape)  # 예: (3, T, 256, 256) 또는 (T, 3, 256, 256)

# clip을 (C, T, H, W)로 통일
if clip.ndim == 4 and clip.shape[0] != 3:
    # (T, C, H, W) → (C, T, H, W)
    if clip.shape[1] == 3:
        clip = clip.permute(1, 0, 2, 3)
    else:
        raise ValueError(f"Unexpected clip shape: {clip.shape}")

print("normalized clip shape:", clip.shape)  # (3, T, H, W)

C, T, H, W = clip.shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 4
#       1 # ---------------------------------------
#       2 # 3) processor로 clip 생성
#       3 # ---------------------------------------
# ----> 4 inputs = processor(buffer)   # 보통 [clip_tensor] 형태
#       6 if isinstance(inputs, list):
#       7     clip = inputs[0]
#
# File ~/.cache\torch\hub\facebookresearch_vjepa2_main\evals\video_classification_frozen\utils.py:108, in VideoTransform.__call__(self, buffer)
#     105 def __call__(self, buffer):
#     107     if not self.training:
# --> 108         return [self.eval_transform(buffer)]
#     110     buffer = [transforms.ToPILImage()(frame) for frame in buffer]
#     112     if self.auto_augment:
#
# File ~/.cache\torch\hub\facebookresearch_vjepa2_main\src\datasets\utils\video\transforms.py:800, in Compose.__call__(self, clip)
#     798 def __call__(self, clip):
#     799     for t in self.transforms:
# --> 800         clip = t(clip)
#     801     return clip
#
# File ~/.cache\torch\hub\facebookresearch_vjepa2_main\src\datasets\utils\video\transforms.py:871, in Resize.__call__(self, clip)
#     870 def __call__(self, clip):
# --> 871     resized = FF.resize_clip(clip, self.size, interpolation=self.interpolation)
#     872     return resized
#
# File ~/.cache\torch\hub\facebookresearch_vjepa2_main\src\datasets\utils\video\functional.py:38, in resize_clip(clip, size, interpolation)
#      37 def resize_clip(clip, size, interpolation="bilinear"):
# ---> 38     if isinstance(clip[0], np.ndarray) or isinstance(clip[0], torch.Tensor):
#      39         if isinstance(size, numbers.Number):
#      40             if clip[0].shape[-1] == 3:
#
# IndexError: list index out of range

# %% [markdown]
# # prefix(처음~t까지) 전체를 요약한 ‘누적 상태’

# %%
# ---------------------------------------
# 4) 누적 world state w_t (t ≥ 2) 계산
# ---------------------------------------
# V-JEPA2 patch_embed3D의 temporal kernel size = 2 이므로
# 최소 T=2 이상부터 입력 가능
min_T = 2
if T < min_T:
    raise ValueError(f"Need at least {min_T} frames, but got T={T}")

w_list = []

for t in range(min_T, T + 1):
    # 앞 t개 프레임 사용: (3, t, H, W)
    clip_t = clip[:, :t, :, :]
    video_t = clip_t.unsqueeze(0).to(device)  # (1, 3, t, H, W)

    with torch.no_grad():
        out_t = vjepa2_encoder(video_t)       # (B, N, D) or dict

    # encoder output에서 토큰 텐서 선택
    if isinstance(out_t, dict):
        if "x" in out_t:
            tokens = out_t["x"]
        else:
            tokens = None
            for k, v in out_t.items():
                if torch.is_tensor(v):
                    tokens = v
                    # print("using key:", k)
                    break
            if tokens is None:
                raise RuntimeError("No tensor output found in encoder dict.")
    else:
        tokens = out_t

    # tokens: (1, N, D) → 평균해서 world state w_t (1, D)
    w_t = tokens.mean(dim=1)
    w_list.append(w_t)

# (T - min_T + 1, D) 형태로 stack
W = torch.cat(w_list, dim=0)  # shape: ((T-1), D)  ← 여기서 첫 행이 w_2에 해당
print("Final W shape:", W.shape)

# %%
# W: shape (T-1, D)  # 여기서는 (7, 1408)
# 인덱스 매핑: W[0] = w2, W[1] = w3, ..., W[6] = w8

# 1) 1차 차분: world-state velocity-like 벡터
vel = W[1:, :] - W[:-1, :]          # shape: (6, 1408)

# 2) 2차 차분: world-state acceleration-like 벡터
acc = vel[1:, :] - vel[:-1, :]      # shape: (5, 1408)

# 3) 간단한 스칼라 지표들
vel_norm_per_step = vel.norm(dim=1)     # (6,) – 각 step마다 state 변화량
acc_norm_per_step = acc.norm(dim=1)     # (5,) – 각 step마다 가속도 변화량

vel_loss  = (vel**2).mean()             # 전체 velocity 에너지
phys_loss = (acc**2).mean()             # 전체 가속도 변화량 (부드러움/물리성)

print("vel_norm_per_step:", vel_norm_per_step)
print("acc_norm_per_step:", acc_norm_per_step)
print("vel_loss:", vel_loss.item())
print("phys_loss:", phys_loss.item())

# %% [markdown]
# # 이전 프레임만 봐야 하는

# %%
C, T, H, W = clip.shape
assert T >= 2

w_list = []
pair_indices = []

for t in range(T - 1):
    clip_pair = clip[:, t:t+2, :, :]                 # (3, 2, H, W)
    video_pair = clip_pair.unsqueeze(0).to(device)   # (1, 3, 2, H, W)

    with torch.no_grad():
        out = vjepa2_encoder(video_pair)

    if isinstance(out, dict):
        tokens = out["x"] if "x" in out else next(v for v in out.values() if torch.is_tensor(v))
    else:
        tokens = out                                  # (1, N, D)

    # (선택) CLS 토큰 제거 시도
    h = H // 16; w = W // 16
    S = h * w
    if tokens.shape[1] == S + 1:                      # CLS + spatial
        tokens = tokens[:, 1:, :]

    w_pair = tokens.mean(dim=1)                       # (1, D)
    w_list.append(w_pair)
    pair_indices.append((t, t+1))

W = torch.cat(w_list, dim=0)                          # (T-1, D)
print("pairs:", pair_indices)
print("W shape:", W.shape)                            # (T-1, D)

vel = W[1:] - W[:-1]                                  # (T-2, D)
acc = vel[1:] - vel[:-1]                              # (T-3, D)

vel_norm_per_step = vel.norm(dim=1)                   # (T-2,)
acc_norm_per_step = acc.norm(dim=1)                   # (T-3,)
vel_loss  = (vel**2).mean()
phys_loss = (acc**2).mean()

print("vel_norm_per_step:", vel_norm_per_step)
print("acc_norm_per_step:", acc_norm_per_step)
print("vel_loss:", vel_loss.item())
print("phys_loss:", phys_loss.item())
